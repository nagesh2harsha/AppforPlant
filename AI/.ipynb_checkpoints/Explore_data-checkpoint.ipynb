# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from shutil import copyfile

# %%
path=r"C:\work\freelancing\plants-collage-project\PlantVillage-Dataset\raw\color"

# %%
for i in os.listdir(path):
    for j in os.listdir(os.path.join(path,i)):
        copyfile(os.path.join(path,i),j)
        break
    break
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-16-afa2bc634405> in <module>
#       1 for i in os.listdir(path):
#       2     for j in os.listdir(os.path.join(path,i)):
# ----> 3         copyfile(os.path.join(path,i),j)
#       4         break
#       5     break
#
# C:\ProgramData\Anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\work\\freelancing\\plants-collage-project\\PlantVillage-Dataset\\raw\\color\\Apple___Apple_scab'

# %%
plt.imshow(img)
